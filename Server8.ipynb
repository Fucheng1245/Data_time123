# %% [markdown]
# Version1:
# Raw Data Processing;

# %%
import torch.utils.data as data
import numpy as np
import os, sys
import data_transforms

import random
import os
import json
import torch
import torchvision.transforms as transforms
import pickle
import math
import time
import io123
IO = io123.IO
all_load_times = []
all_process_times = []

def rotation_z(pts, theta):
    cos_theta = np.cos(theta)
    sin_theta = np.sin(theta)
    rotation_matrix = np.array([[cos_theta, -sin_theta, 0.0],
                                [sin_theta, cos_theta, 0.0],
                                [0.0, 0.0, 1.0]])
    return pts @ rotation_matrix.T


def rotation_y(pts, theta):
    cos_theta = np.cos(theta)
    sin_theta = np.sin(theta)
    rotation_matrix = np.array([[cos_theta, 0.0, -sin_theta],
                                [0.0, 1.0, 0.0],
                                [sin_theta, 0.0, cos_theta]])
    return pts @ rotation_matrix.T


def rotation_x(pts, theta):
    cos_theta = np.cos(theta)
    sin_theta = np.sin(theta)
    rotation_matrix = np.array([[1.0, 0.0, 0.0],
                                [0.0, cos_theta, -sin_theta],
                                [0.0, sin_theta, cos_theta]])
    return pts @ rotation_matrix.T


class Shapenet_ViPC(data.Dataset):
    # def __init__(self, data_root, subset, class_choice = None):
    def __init__(self, subset,View_align):
        self.partial_points_path = "./data/Partial/%s/%s/%s.dat"
        self.complete_points_path = "./data/GT/%s/%s/%s.dat"
        self.view_path = "./data/view/%s/%s/rendering/%s.png"
        self.category_file = "%s_list2.txt"
        self.npoints = 3500
        self.subset = subset
        self.category = "all" 
        self.cat_map = {
            'plane':'02691156',
            'bench': '02828884', 
            'cabinet':'02933112', 
            'car':'02958343',
            'chair':'03001627',
            'monitor': '03211117',
            'lamp':'03636649',
            'speaker': '03691459', 
            'firearm': '04090263', 
            'couch':'04256520',
            'table':'04379243',
            'cellphone': '04401088', 
            'watercraft':'04530566'
        }
        self.filelist = []
        self.cat = []
        self.key = []
        self.filepath = self.category_file % self.subset
        self.view_align = View_align

        with open(self.filepath,'r') as f:
            line = f.readline()
            while (line):
                self.filelist.append(line)
                line = f.readline()

        for key in self.filelist:
            if self.category !='all':
                if key.split(';')[0]!= self.cat_map[self.category]:
                    continue
            self.cat.append(key.split(';')[0])
            self.key.append(key)
        self.img_transforms = self._img_get_transforms(self.subset)

    def _img_get_transforms(self,subset):
        if subset == 'train':
            transform1 = transforms.Compose([
                transforms.Resize(224),
                transforms.ToTensor(),   
               
            ])
        else:
            transform1 = transforms.Compose([ 
                transforms.Resize(224),
                transforms.ToTensor(),   
            ])
        return transform1


    def __getitem__(self, idx):

        data_loading_time = 0
        data_processing_time = 0
        
        key = self.key[idx]
        pc_part_path = self.partial_points_path % (key.split(';')[0],key.split(';')[1], key.split(';')[-1].replace('\n', ''))
        # pc_part_path = os.path.join(self.imcomplete_path,key.split(';')[0]+'/'+ key.split(';')[1]+'/'+key.split(';')[-1].replace('\n', '')+'.dat')
        
        if self.view_align:
            ran_key = key        
        else:
            ran_key = key[:-3]+str(random.randint(0,23)).rjust(2,'0')
        
        pc_path = self.complete_points_path % (ran_key.split(';')[0], ran_key.split(';')[1], ran_key.split(';')[-1].replace('\n', ''))
        # pc_path = os.path.join(self.gt_path, ran_key.split(';')[0]+'/'+ ran_key.split(';')[1]+'/'+ran_key.split(';')[-1].replace('\n', '')+'.dat')
        view_path = self.view_path % (ran_key.split(';')[0], ran_key.split(';')[1], ran_key.split(';')[-1].replace('\n','')) 
        if(len(ran_key.split(';')[-1])>3):
            print("bug")
            print(ran_key.split(';')[-1])
            fin = ran_key.split(';')[-1][-2:]
            interm = ran_key.split(';')[-1][:-2]
            pc_path = self.complete_points_path % (ran_key.split(';')[0],  interm +'/', fin.replace('\n', ''))          
            view_path = self.view_path % (ran_key.split(';')[0]+ '/', interm , fin.replace('\n',''))
        
        load_start_time = time.time()
        views = IO.get(view_path)
        # load gt points
        with open(pc_path,'rb') as f:
            pc = pickle.load(f).astype(np.float32)
        # load partial points
        with open(pc_part_path,'rb') as f:
            pc_part = pickle.load(f).astype(np.float32)

        view_metadata = np.loadtxt(view_path[:-6]+'rendering_metadata.txt')

        data_loading_time = time.time() - load_start_time

        process_start_time = time.time()
        # incase some item point number less than 3500 
        if pc_part.shape[0]<self.npoints:
            pc_part = np.repeat(pc_part,(self.npoints//pc_part.shape[0])+1,axis=0)[0:self.npoints]
        views = self.img_transforms(views)
        views = views[:3,:,:]

        
        # load the view metadata
        image_view_id = view_path.split('/')[-1].split('.')[0]
        part_view_id = pc_part_path.split('/')[-1].split('.')[0]
        # print(pc_path)
        # print(view_path)
        # print(image_view_id)
        # print(part_view_id)

        theta_part = math.radians(view_metadata[int(part_view_id),0])
        phi_part = math.radians(view_metadata[int(part_view_id),1])

        theta_img = math.radians(view_metadata[int(image_view_id),0])
        phi_img = math.radians(view_metadata[int(image_view_id),1])

        pc_part = rotation_y(rotation_x(pc_part, - phi_part),np.pi + theta_part)
        pc_part = rotation_x(rotation_y(pc_part, np.pi - theta_img), phi_img)

        # normalize partial point cloud and GT to the same scale
        gt_mean = pc.mean(axis=0) 
        pc = pc - gt_mean
        pc_L_max = np.max(np.sqrt(np.sum(abs(pc ** 2), axis=-1)))
        pc = pc/pc_L_max

        pc_part = pc_part-gt_mean
        pc_part = pc_part/pc_L_max

        data_processing_time = time.time()-process_start_time
  

        return ran_key.split(';')[0], ran_key.split(';')[1], (torch.from_numpy(pc_part).float(), torch.from_numpy(pc).float(),views.float()),torch.tensor(data_loading_time), torch.tensor(data_processing_time)
    
    def __len__(self):
        return len(self.key)

train_data = Shapenet_ViPC("train",True)
test_data = Shapenet_ViPC("test",True)

# %%
! pip install h5py
# Out:
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple
# Collecting h5py
#   Downloading https://mirrors.aliyun.com/pypi/packages/95/be/de1e591bec008ed92d3829b985757b8bc2d34179feef5e181530876a4f9d/h5py-3.8.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 858.6 kB/s eta 0:00:0000:0100:01
# Requirement already satisfied: numpy>=1.14.5 in /home_exp_2/fucheng.niu/anaconda3/envs/DBGANet1/lib/python3.7/site-packages (from h5py) (1.21.6)
# Installing collected packages: h5py
# Successfully installed h5py-3.8.0

# %%
shuffle = 1

# %%
def data_test(bs,num_workers):
    def worker_init_fn(worker_id):
        np.random.seed(np.random.get_state()[1][0] + worker_id)

    train_dataloader = torch.utils.data.DataLoader(train_data, batch_size=bs,
                                                        shuffle = shuffle, 
                                                        drop_last = True,
                                                        num_workers = num_workers,
                                                        worker_init_fn=worker_init_fn,
                                                        pin_memory = True)

    test_dataloader = torch.utils.data.DataLoader(test_data, batch_size=bs,
                                                        shuffle = shuffle, 
                                                        drop_last = False,
                                                        num_workers = num_workers,
                                                        worker_init_fn=worker_init_fn,
                                                        pin_memory = True)
    max_epoch =10

    all_data_times = []

    all_load_times = []
    all_process_times = []

    for epoch in range(0, max_epoch + 1):
        batch_start_time = time.time()
        n_batches = len(train_dataloader)
        epoch_data_times = []
        for idx, (taxonomy_ids, model_ids, data,load_times,process_times) in enumerate(train_dataloader):
                # print("data2:",data[0].shape)
                data_time= time.time() - batch_start_time 
                if num_workers !=0:
                    load_times = load_times.reshape(-1).sum()
                    process_times = process_times.reshape(-1).sum()
                else:
                    load_times = load_times.reshape(-1).sum()
                    process_times = process_times.reshape(-1).sum() 
                # print(load_times.shape)
                print('[Epoch %d/%d][Batch %d/%d] DataTime = %.3f (s) LoadTime = %f(s) ProcessTime = %f(s)' %
                                (epoch, max_epoch, idx + 1, n_batches, data_time,load_times,process_times))
                all_data_times.append(data_time)

                # load_times = load_times.reshape(-1).mean()
                # process_times = process_times.reshape(-1).mean()
                all_load_times.append(load_times)
                all_process_times.append(process_times)
                batch_start_time = time.time()

                
    import matplotlib.pyplot as plt
    mean_load_time = sum(all_load_times) / len(all_load_times)
    mean_process_time = sum(all_process_times) / len(all_process_times)
    mean_data_time = sum(all_data_times) / len(all_data_times)

    # 绘制图像
    plt.figure(figsize=(10, 6))
    plt.plot(all_data_times, label="Total Data Time per Batch", color='b')
    plt.plot(all_load_times, label="Data Loading Time", color='g')
    plt.plot(all_process_times, label="Data Processing Time", color='orange')

    plt.axhline(mean_data_time, color='r', linestyle='--', label=f"Mean Total Time = {mean_data_time:.3f} s")
    plt.axhline(mean_load_time, color='g', linestyle='--', label=f"Mean Load Time = {mean_load_time:.3f} s")
    plt.axhline(mean_process_time, color='orange', linestyle='--', label=f"Mean Process Time = {mean_process_time:.3f} s")
    plt.yticks([mean_load_time,mean_process_time,mean_data_time])

    plt.xlabel('Batch')
    plt.ylabel('Time (s)')
    plt.title(f'Batchsize:{bs}, Num_workers:{num_workers}')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
parmaters = [[64,0],[64,1],[64,2],[64,4]]

for par in parmaters:
    data_test(*par)
# Out:
# [Epoch 0/10][Batch 1/3] DataTime = 0.136 (s) LoadTime = 0.028282(s) ProcessTime = 0.087219(s)
# [Epoch 0/10][Batch 2/3] DataTime = 0.132 (s) LoadTime = 0.027276(s) ProcessTime = 0.084732(s)
# [Epoch 0/10][Batch 3/3] DataTime = 0.124 (s) LoadTime = 0.027101(s) ProcessTime = 0.080292(s)
# [Epoch 1/10][Batch 1/3] DataTime = 0.121 (s) LoadTime = 0.026563(s) ProcessTime = 0.078638(s)
# [Epoch 1/10][Batch 2/3] DataTime = 0.120 (s) LoadTime = 0.026895(s) ProcessTime = 0.079078(s)
# [Epoch 1/10][Batch 3/3] DataTime = 0.118 (s) LoadTime = 0.026630(s) ProcessTime = 0.076529(s)
# [Epoch 2/10][Batch 1/3] DataTime = 0.119 (s) LoadTime = 0.026752(s) ProcessTime = 0.077467(s)
# [Epoch 2/10][Batch 2/3] DataTime = 0.117 (s) LoadTime = 0.026452(s) ProcessTime = 0.076512(s)
# [Epoch 2/10][Batch 3/3] DataTime = 0.118 (s) LoadTime = 0.026983(s) ProcessTime = 0.076569(s)
# [Epoch 3/10][Batch 1/3] DataTime = 0.117 (s) LoadTime = 0.026428(s) ProcessTime = 0.076410(s)
# [Epoch 3/10][Batch 2/3] DataTime = 0.118 (s) LoadTime = 0.026649(s) ProcessTime = 0.077300(s)
# [Epoch 3/10][Batch 3/3] DataTime = 0.118 (s) LoadTime = 0.026502(s) ProcessTime = 0.076514(s)
# [Epoch 4/10][Batch 1/3] DataTime = 0.118 (s) LoadTime = 0.026655(s) ProcessTime = 0.077267(s)
# [Epoch 4/10][Batch 2/3] DataTime = 0.119 (s) LoadTime = 0.026685(s) ProcessTime = 0.076886(s)
# [Epoch 4/10][Batch 3/3] DataTime = 0.119 (s) LoadTime = 0.027255(s) ProcessTime = 0.077403(s)
# [Epoch 5/10][Batch 1/3] DataTime = 0.118 (s) LoadTime = 0.026514(s) ProcessTime = 0.076971(s)
# [Epoch 5/10][Batch 2/3] DataTime = 0.119 (s) LoadTime = 0.026754(s) ProcessTime = 0.077286(s)
# [Epoch 5/10][Batch 3/3] DataTime = 0.117 (s) LoadTime = 0.026430(s) ProcessTime = 0.076409(s)
# [Epoch 6/10][Batch 1/3] DataTime = 0.118 (s) LoadTime = 0.026649(s) ProcessTime = 0.076454(s)
# [Epoch 6/10][Batch 2/3] DataTime = 0.118 (s) LoadTime = 0.026484(s) ProcessTime = 0.077090(s)
# [Epoch 6/10][Batch 3/3] DataTime = 0.118 (s) LoadTime = 0.026712(s) ProcessTime = 0.077201(s)
# [Epoch 7/10][Batch 1/3] DataTime = 0.118 (s) LoadTime = 0.026523(s) ProcessTime = 0.076854(s)
# [Epoch 7/10][Batch 2/3] DataTime = 0.123 (s) LoadTime = 0.028123(s) ProcessTime = 0.080154(s)
# [Epoch 7/10][Batch 3/3] DataTime = 0.117 (s) LoadTime = 0.026435(s) ProcessTime = 0.076413(s)
# [Epoch 8/10][Batch 1/3] DataTime = 0.118 (s) LoadTime = 0.027011(s) ProcessTime = 0.076576(s)
# [Epoch 8/10][Batch 2/3] DataTime = 0.118 (s) LoadTime = 0.026485(s) ProcessTime = 0.076690(s)
# [Epoch 8/10][Batch 3/3] DataTime = 0.125 (s) LoadTime = 0.026982(s) ProcessTime = 0.079892(s)
# [Epoch 9/10][Batch 1/3] DataTime = 0.119 (s) LoadTime = 0.026449(s) ProcessTime = 0.077250(s)
# [Epoch 9/10][Batch 2/3] DataTime = 0.118 (s) LoadTime = 0.026677(s) ProcessTime = 0.076881(s)
# [Epoch 9/10][Batch 3/3] DataTime = 0.118 (s) LoadTime = 0.026472(s) ProcessTime = 0.076573(s)
# [Epoch 10/10][Batch 1/3] DataTime = 0.118 (s) LoadTime = 0.027109(s) ProcessTime = 0.076815(s)
# [Epoch 10/10][Batch 2/3] DataTime = 0.118 (s) LoadTime = 0.026390(s) ProcessTime = 0.076708(s)
# [Epoch 10/10][Batch 3/3] DataTime = 0.118 (s) LoadTime = 0.026980(s) ProcessTime = 0.076713(s)
# [Epoch 0/10][Batch 1/3] DataTime = 0.190 (s) LoadTime = 0.028285(s) ProcessTime = 0.106612(s)
# [Epoch 0/10][Batch 2/3] DataTime = 0.132 (s) LoadTime = 0.027495(s) ProcessTime = 0.085858(s)
# [Epoch 0/10][Batch 3/3] DataTime = 0.131 (s) LoadTime = 0.029510(s) ProcessTime = 0.084771(s)
# [Epoch 1/10][Batch 1/3] DataTime = 0.186 (s) LoadTime = 0.027735(s) ProcessTime = 0.104191(s)
# [Epoch 1/10][Batch 2/3] DataTime = 0.130 (s) LoadTime = 0.027213(s) ProcessTime = 0.086242(s)
# [Epoch 1/10][Batch 3/3] DataTime = 0.131 (s) LoadTime = 0.028610(s) ProcessTime = 0.084628(s)
# [Epoch 2/10][Batch 1/3] DataTime = 0.187 (s) LoadTime = 0.027951(s) ProcessTime = 0.105176(s)
# [Epoch 2/10][Batch 2/3] DataTime = 0.130 (s) LoadTime = 0.027175(s) ProcessTime = 0.085656(s)
# [Epoch 2/10][Batch 3/3] DataTime = 0.131 (s) LoadTime = 0.028940(s) ProcessTime = 0.084831(s)
# [Epoch 3/10][Batch 1/3] DataTime = 0.188 (s) LoadTime = 0.028112(s) ProcessTime = 0.104668(s)
# [Epoch 3/10][Batch 2/3] DataTime = 0.129 (s) LoadTime = 0.027657(s) ProcessTime = 0.085683(s)
# [Epoch 3/10][Batch 3/3] DataTime = 0.131 (s) LoadTime = 0.028682(s) ProcessTime = 0.084869(s)
# [Epoch 4/10][Batch 1/3] DataTime = 0.188 (s) LoadTime = 0.028201(s) ProcessTime = 0.105535(s)
# [Epoch 4/10][Batch 2/3] DataTime = 0.130 (s) LoadTime = 0.028190(s) ProcessTime = 0.085519(s)
# [Epoch 4/10][Batch 3/3] DataTime = 0.132 (s) LoadTime = 0.029090(s) ProcessTime = 0.085265(s)
# [Epoch 5/10][Batch 1/3] DataTime = 0.187 (s) LoadTime = 0.027720(s) ProcessTime = 0.104520(s)
# [Epoch 5/10][Batch 2/3] DataTime = 0.134 (s) LoadTime = 0.027358(s) ProcessTime = 0.091034(s)
# [Epoch 5/10][Batch 3/3] DataTime = 0.129 (s) LoadTime = 0.027090(s) ProcessTime = 0.083772(s)
# [Epoch 6/10][Batch 1/3] DataTime = 0.188 (s) LoadTime = 0.028383(s) ProcessTime = 0.105355(s)
# [Epoch 6/10][Batch 2/3] DataTime = 0.129 (s) LoadTime = 0.027091(s) ProcessTime = 0.085018(s)
# [Epoch 6/10][Batch 3/3] DataTime = 0.129 (s) LoadTime = 0.028543(s) ProcessTime = 0.083551(s)
# [Epoch 7/10][Batch 1/3] DataTime = 0.189 (s) LoadTime = 0.028227(s) ProcessTime = 0.107490(s)
# [Epoch 7/10][Batch 2/3] DataTime = 0.130 (s) LoadTime = 0.028562(s) ProcessTime = 0.084208(s)
# [Epoch 7/10][Batch 3/3] DataTime = 0.131 (s) LoadTime = 0.028463(s) ProcessTime = 0.085439(s)
# [Epoch 8/10][Batch 1/3] DataTime = 0.186 (s) LoadTime = 0.028023(s) ProcessTime = 0.104702(s)
# [Epoch 8/10][Batch 2/3] DataTime = 0.130 (s) LoadTime = 0.028607(s) ProcessTime = 0.084117(s)
# [Epoch 8/10][Batch 3/3] DataTime = 0.130 (s) LoadTime = 0.026731(s) ProcessTime = 0.083244(s)
# [Epoch 9/10][Batch 1/3] DataTime = 0.187 (s) LoadTime = 0.027477(s) ProcessTime = 0.104426(s)
# [Epoch 9/10][Batch 2/3] DataTime = 0.128 (s) LoadTime = 0.026724(s) ProcessTime = 0.084732(s)
# [Epoch 9/10][Batch 3/3] DataTime = 0.129 (s) LoadTime = 0.027928(s) ProcessTime = 0.083520(s)
# [Epoch 10/10][Batch 1/3] DataTime = 0.185 (s) LoadTime = 0.027498(s) ProcessTime = 0.104144(s)
# [Epoch 10/10][Batch 2/3] DataTime = 0.130 (s) LoadTime = 0.029289(s) ProcessTime = 0.084278(s)
# [Epoch 10/10][Batch 3/3] DataTime = 0.130 (s) LoadTime = 0.027086(s) ProcessTime = 0.083747(s)
# [Epoch 0/10][Batch 1/3] DataTime = 0.228 (s) LoadTime = 0.031199(s) ProcessTime = 0.109883(s)
# [Epoch 0/10][Batch 2/3] DataTime = 0.000 (s) LoadTime = 0.030788(s) ProcessTime = 0.109938(s)
# [Epoch 0/10][Batch 3/3] DataTime = 0.183 (s) LoadTime = 0.032439(s) ProcessTime = 0.095888(s)
# [Epoch 1/10][Batch 1/3] DataTime = 0.202 (s) LoadTime = 0.030352(s) ProcessTime = 0.108645(s)
# [Epoch 1/10][Batch 2/3] DataTime = 0.017 (s) LoadTime = 0.030863(s) ProcessTime = 0.109421(s)
# [Epoch 1/10][Batch 3/3] DataTime = 0.179 (s) LoadTime = 0.094052(s) ProcessTime = 0.087385(s)
# [Epoch 2/10][Batch 1/3] DataTime = 0.293 (s) LoadTime = 0.030668(s) ProcessTime = 0.108819(s)
# [Epoch 2/10][Batch 2/3] DataTime = 0.000 (s) LoadTime = 0.030262(s) ProcessTime = 0.108339(s)
# [Epoch 2/10][Batch 3/3] DataTime = 0.122 (s) LoadTime = 0.031015(s) ProcessTime = 0.100187(s)
# [Epoch 3/10][Batch 1/3] DataTime = 0.294 (s) LoadTime = 0.103214(s) ProcessTime = 0.109842(s)
# [Epoch 3/10][Batch 2/3] DataTime = 0.000 (s) LoadTime = 0.098631(s) ProcessTime = 0.108754(s)
# [Epoch 3/10][Batch 3/3] DataTime = 0.126 (s) LoadTime = 0.031214(s) ProcessTime = 0.097296(s)
# [Epoch 4/10][Batch 1/3] DataTime = 0.268 (s) LoadTime = 0.098786(s) ProcessTime = 0.108460(s)
# [Epoch 4/10][Batch 2/3] DataTime = 0.017 (s) LoadTime = 0.099262(s) ProcessTime = 0.108571(s)
# [Epoch 4/10][Batch 3/3] DataTime = 0.114 (s) LoadTime = 0.028755(s) ProcessTime = 0.086871(s)
# [Epoch 5/10][Batch 1/3] DataTime = 0.270 (s) LoadTime = 0.098864(s) ProcessTime = 0.108852(s)
# [Epoch 5/10][Batch 2/3] DataTime = 0.017 (s) LoadTime = 0.099928(s) ProcessTime = 0.108797(s)
# [Epoch 5/10][Batch 3/3] DataTime = 0.111 (s) LoadTime = 0.027236(s) ProcessTime = 0.086335(s)
# [Epoch 6/10][Batch 1/3] DataTime = 0.288 (s) LoadTime = 0.099343(s) ProcessTime = 0.108748(s)
# [Epoch 6/10][Batch 2/3] DataTime = 0.000 (s) LoadTime = 0.099216(s) ProcessTime = 0.108247(s)
# [Epoch 6/10][Batch 3/3] DataTime = 0.111 (s) LoadTime = 0.027799(s) ProcessTime = 0.086670(s)
# [Epoch 7/10][Batch 1/3] DataTime = 0.270 (s) LoadTime = 0.099146(s) ProcessTime = 0.109336(s)
# [Epoch 7/10][Batch 2/3] DataTime = 0.017 (s) LoadTime = 0.099764(s) ProcessTime = 0.109292(s)
# [Epoch 7/10][Batch 3/3] DataTime = 0.114 (s) LoadTime = 0.027071(s) ProcessTime = 0.088291(s)
# [Epoch 8/10][Batch 1/3] DataTime = 0.288 (s) LoadTime = 0.099453(s) ProcessTime = 0.108908(s)
# [Epoch 8/10][Batch 2/3] DataTime = 0.000 (s) LoadTime = 0.099389(s) ProcessTime = 0.108757(s)
# [Epoch 8/10][Batch 3/3] DataTime = 0.112 (s) LoadTime = 0.027761(s) ProcessTime = 0.086517(s)
# [Epoch 9/10][Batch 1/3] DataTime = 0.287 (s) LoadTime = 0.099489(s) ProcessTime = 0.109499(s)
# [Epoch 9/10][Batch 2/3] DataTime = 0.000 (s) LoadTime = 0.099343(s) ProcessTime = 0.108615(s)
# [Epoch 9/10][Batch 3/3] DataTime = 0.112 (s) LoadTime = 0.027010(s) ProcessTime = 0.085999(s)
# [Epoch 10/10][Batch 1/3] DataTime = 0.286 (s) LoadTime = 0.099610(s) ProcessTime = 0.109108(s)
# [Epoch 10/10][Batch 2/3] DataTime = 0.000 (s) LoadTime = 0.099321(s) ProcessTime = 0.108299(s)
# [Epoch 10/10][Batch 3/3] DataTime = 0.112 (s) LoadTime = 0.027399(s) ProcessTime = 0.085699(s)
# [Epoch 0/10][Batch 1/3] DataTime = 0.243 (s) LoadTime = 0.035279(s) ProcessTime = 0.122948(s)
# [Epoch 0/10][Batch 2/3] DataTime = 0.017 (s) LoadTime = 0.035378(s) ProcessTime = 0.122537(s)
# [Epoch 0/10][Batch 3/3] DataTime = 0.016 (s) LoadTime = 0.036503(s) ProcessTime = 0.123832(s)
# [Epoch 1/10][Batch 1/3] DataTime = 0.252 (s) LoadTime = 0.034463(s) ProcessTime = 0.117909(s)
# [Epoch 1/10][Batch 2/3] DataTime = 0.000 (s) LoadTime = 0.034347(s) ProcessTime = 0.117893(s)
# [Epoch 1/10][Batch 3/3] DataTime = 0.016 (s) LoadTime = 0.034166(s) ProcessTime = 0.117917(s)
# [Epoch 2/10][Batch 1/3] DataTime = 0.251 (s) LoadTime = 0.034134(s) ProcessTime = 0.116705(s)
# [Epoch 2/10][Batch 2/3] DataTime = 0.000 (s) LoadTime = 0.034085(s) ProcessTime = 0.116645(s)
# [Epoch 2/10][Batch 3/3] DataTime = 0.016 (s) LoadTime = 0.033675(s) ProcessTime = 0.116988(s)
# [Epoch 3/10][Batch 1/3] DataTime = 0.253 (s) LoadTime = 0.034275(s) ProcessTime = 0.117287(s)
# [Epoch 3/10][Batch 2/3] DataTime = 0.000 (s) LoadTime = 0.034108(s) ProcessTime = 0.117273(s)
# [Epoch 3/10][Batch 3/3] DataTime = 0.016 (s) LoadTime = 0.033976(s) ProcessTime = 0.117311(s)
# [Epoch 4/10][Batch 1/3] DataTime = 0.252 (s) LoadTime = 0.034184(s) ProcessTime = 0.117459(s)
# [Epoch 4/10][Batch 2/3] DataTime = 0.000 (s) LoadTime = 0.034125(s) ProcessTime = 0.117383(s)
# [Epoch 4/10][Batch 3/3] DataTime = 0.016 (s) LoadTime = 0.034017(s) ProcessTime = 0.117367(s)
# [Epoch 5/10][Batch 1/3] DataTime = 0.235 (s) LoadTime = 0.034248(s) ProcessTime = 0.117629(s)
# [Epoch 5/10][Batch 2/3] DataTime = 0.017 (s) LoadTime = 0.034165(s) ProcessTime = 0.117475(s)
# [Epoch 5/10][Batch 3/3] DataTime = 0.017 (s) LoadTime = 0.034174(s) ProcessTime = 0.117364(s)
# [Epoch 6/10][Batch 1/3] DataTime = 0.251 (s) LoadTime = 0.034196(s) ProcessTime = 0.117484(s)
# [Epoch 6/10][Batch 2/3] DataTime = 0.000 (s) LoadTime = 0.034249(s) ProcessTime = 0.117307(s)
# [Epoch 6/10][Batch 3/3] DataTime = 0.016 (s) LoadTime = 0.034092(s) ProcessTime = 0.117346(s)
# [Epoch 7/10][Batch 1/3] DataTime = 0.235 (s) LoadTime = 0.034266(s) ProcessTime = 0.117436(s)
# [Epoch 7/10][Batch 2/3] DataTime = 0.017 (s) LoadTime = 0.034059(s) ProcessTime = 0.117465(s)
# [Epoch 7/10][Batch 3/3] DataTime = 0.016 (s) LoadTime = 0.034045(s) ProcessTime = 0.117343(s)
# [Epoch 8/10][Batch 1/3] DataTime = 0.234 (s) LoadTime = 0.034244(s) ProcessTime = 0.117267(s)
# [Epoch 8/10][Batch 2/3] DataTime = 0.017 (s) LoadTime = 0.034163(s) ProcessTime = 0.117225(s)
# [Epoch 8/10][Batch 3/3] DataTime = 0.017 (s) LoadTime = 0.034139(s) ProcessTime = 0.117079(s)
# [Epoch 9/10][Batch 1/3] DataTime = 0.235 (s) LoadTime = 0.034250(s) ProcessTime = 0.117356(s)
# [Epoch 9/10][Batch 2/3] DataTime = 0.017 (s) LoadTime = 0.034240(s) ProcessTime = 0.117133(s)
# [Epoch 9/10][Batch 3/3] DataTime = 0.017 (s) LoadTime = 0.034102(s) ProcessTime = 0.117162(s)
# [Epoch 10/10][Batch 1/3] DataTime = 0.227 (s) LoadTime = 0.032164(s) ProcessTime = 0.111248(s)
# [Epoch 10/10][Batch 2/3] DataTime = 0.088 (s) LoadTime = 0.048140(s) ProcessTime = 0.176539(s)
# [Epoch 10/10][Batch 3/3] DataTime = 0.016 (s) LoadTime = 0.048154(s) ProcessTime = 0.176437(s)
