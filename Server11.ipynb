# %%
import torch.utils.data as data
import numpy as np
import os, sys
import data_transforms

import random
import os
import json
import torch
import torchvision.transforms as transforms
import pickle
import math
import time
import io123
IO = io123.IO
all_load_times = []
all_process_times = []

def rotation_z(pts, theta):
    cos_theta = np.cos(theta)
    sin_theta = np.sin(theta)
    rotation_matrix = np.array([[cos_theta, -sin_theta, 0.0],
                                [sin_theta, cos_theta, 0.0],
                                [0.0, 0.0, 1.0]])
    return pts @ rotation_matrix.T


def rotation_y(pts, theta):
    cos_theta = np.cos(theta)
    sin_theta = np.sin(theta)
    rotation_matrix = np.array([[cos_theta, 0.0, -sin_theta],
                                [0.0, 1.0, 0.0],
                                [sin_theta, 0.0, cos_theta]])
    return pts @ rotation_matrix.T


def rotation_x(pts, theta):
    cos_theta = np.cos(theta)
    sin_theta = np.sin(theta)
    rotation_matrix = np.array([[1.0, 0.0, 0.0],
                                [0.0, cos_theta, -sin_theta],
                                [0.0, sin_theta, cos_theta]])
    return pts @ rotation_matrix.T


class Shapenet_ViPC(data.Dataset):
    # def __init__(self, data_root, subset, class_choice = None):
    def __init__(self, subset,View_align):
        self.partial_points_path = "./data/Partial/%s/%s/%s.dat"
        self.complete_points_path = "./data/GT/%s/%s/%s.dat"
        self.view_path = "./data/view/%s/%s/rendering/%s.png"
        self.category_file = "%s_list2.txt"
        self.npoints = 3500
        self.subset = subset
        self.category = "all" 
        self.cat_map = {
            'plane':'02691156',
            'bench': '02828884', 
            'cabinet':'02933112', 
            'car':'02958343',
            'chair':'03001627',
            'monitor': '03211117',
            'lamp':'03636649',
            'speaker': '03691459', 
            'firearm': '04090263', 
            'couch':'04256520',
            'table':'04379243',
            'cellphone': '04401088', 
            'watercraft':'04530566'
        }
        self.filelist = []
        self.cat = []
        self.key = []
        self.filepath = self.category_file % self.subset
        self.view_align = View_align

        with open(self.filepath,'r') as f:
            line = f.readline()
            while (line):
                self.filelist.append(line)
                line = f.readline()

        for key in self.filelist:
            if self.category !='all':
                if key.split(';')[0]!= self.cat_map[self.category]:
                    continue
            self.cat.append(key.split(';')[0])
            self.key.append(key)
        self.img_transforms = self._img_get_transforms(self.subset)

    def _img_get_transforms(self,subset):
        if subset == 'train':
            transform1 = transforms.Compose([
                transforms.Resize(224),
                transforms.ToTensor(),   
               
            ])
        else:
            transform1 = transforms.Compose([ 
                transforms.Resize(224),
                transforms.ToTensor(),   
            ])
        return transform1


    def __getitem__(self, idx):

        data_loading_time = 0
        data_processing_time = 0
        
        key = self.key[idx]
        pc_part_path = self.partial_points_path % (key.split(';')[0],key.split(';')[1], key.split(';')[-1].replace('\n', ''))
        # pc_part_path = os.path.join(self.imcomplete_path,key.split(';')[0]+'/'+ key.split(';')[1]+'/'+key.split(';')[-1].replace('\n', '')+'.dat')
        
        if self.view_align:
            ran_key = key        
        else:
            ran_key = key[:-3]+str(random.randint(0,23)).rjust(2,'0')
        
        pc_path = self.complete_points_path % (ran_key.split(';')[0], ran_key.split(';')[1], ran_key.split(';')[-1].replace('\n', ''))
        # pc_path = os.path.join(self.gt_path, ran_key.split(';')[0]+'/'+ ran_key.split(';')[1]+'/'+ran_key.split(';')[-1].replace('\n', '')+'.dat')
        view_path = self.view_path % (ran_key.split(';')[0], ran_key.split(';')[1], ran_key.split(';')[-1].replace('\n','')) 
        if(len(ran_key.split(';')[-1])>3):
            print("bug")
            print(ran_key.split(';')[-1])
            fin = ran_key.split(';')[-1][-2:]
            interm = ran_key.split(';')[-1][:-2]
            pc_path = self.complete_points_path % (ran_key.split(';')[0],  interm +'/', fin.replace('\n', ''))          
            view_path = self.view_path % (ran_key.split(';')[0]+ '/', interm , fin.replace('\n',''))
        
        load_start_time = time.time()
        views = IO.get(view_path)
        # load gt points
        with open(pc_path,'rb') as f:
            pc = pickle.load(f).astype(np.float32)
        # load partial points
        with open(pc_part_path,'rb') as f:
            pc_part = pickle.load(f).astype(np.float32)

        view_metadata = np.loadtxt(view_path[:-6]+'rendering_metadata.txt')

        data_loading_time = time.time() - load_start_time

        process_start_time = time.time()
        # incase some item point number less than 3500 
        if pc_part.shape[0]<self.npoints:
            pc_part = np.repeat(pc_part,(self.npoints//pc_part.shape[0])+1,axis=0)[0:self.npoints]
        views = self.img_transforms(views)
        views = views[:3,:,:]

        
        # load the view metadata
        image_view_id = view_path.split('/')[-1].split('.')[0]
        part_view_id = pc_part_path.split('/')[-1].split('.')[0]
        # print(pc_path)
        # print(view_path)
        # print(image_view_id)
        # print(part_view_id)

        theta_part = math.radians(view_metadata[int(part_view_id),0])
        phi_part = math.radians(view_metadata[int(part_view_id),1])

        theta_img = math.radians(view_metadata[int(image_view_id),0])
        phi_img = math.radians(view_metadata[int(image_view_id),1])

        pc_part = rotation_y(rotation_x(pc_part, - phi_part),np.pi + theta_part)
        pc_part = rotation_x(rotation_y(pc_part, np.pi - theta_img), phi_img)

        # normalize partial point cloud and GT to the same scale
        gt_mean = pc.mean(axis=0) 
        pc = pc - gt_mean
        pc_L_max = np.max(np.sqrt(np.sum(abs(pc ** 2), axis=-1)))
        pc = pc/pc_L_max

        pc_part = pc_part-gt_mean
        pc_part = pc_part/pc_L_max

        data_processing_time = time.time()-process_start_time
  

        return ran_key.split(';')[0], ran_key.split(';')[1], (torch.from_numpy(pc_part).float(), torch.from_numpy(pc).float(),views.float()),torch.tensor(data_loading_time), torch.tensor(data_processing_time)
    
    def __len__(self):
        return len(self.key)

train_data = Shapenet_ViPC("train",True)
test_data = Shapenet_ViPC("test",True)

# %%
shuffle = 1

# %%
def data_test(bs,num_workers):
    def worker_init_fn(worker_id):
        np.random.seed(np.random.get_state()[1][0] + worker_id)

    train_dataloader = torch.utils.data.DataLoader(train_data, batch_size=bs,
                                                        shuffle = shuffle, 
                                                        drop_last = True,
                                                        num_workers = num_workers,
                                                        worker_init_fn=worker_init_fn,
                                                        pin_memory = True)

    test_dataloader = torch.utils.data.DataLoader(test_data, batch_size=bs,
                                                        shuffle = shuffle, 
                                                        drop_last = False,
                                                        num_workers = num_workers,
                                                        worker_init_fn=worker_init_fn,
                                                        pin_memory = True)
    max_epoch =10

    all_data_times = []

    all_load_times = []
    all_process_times = []

    for epoch in range(0, max_epoch + 1):
        batch_start_time = time.time()
        n_batches = len(train_dataloader)
        epoch_data_times = []
        for idx, (taxonomy_ids, model_ids, data,load_times,process_times) in enumerate(train_dataloader):
                # print("data2:",data[0].shape)
                data_time= time.time() - batch_start_time 
                if num_workers !=0:
                    load_times = load_times.reshape(-1).sum()
                    process_times = process_times.reshape(-1).sum() 
                else:
                    load_times = load_times.reshape(-1).sum()
                    process_times = process_times.reshape(-1).sum() 
                # print(load_times.shape)
                print('[Epoch %d/%d][Batch %d/%d] DataTime = %.3f (s) LoadTime = %f(s) ProcessTime = %f(s)' %
                                (epoch, max_epoch, idx + 1, n_batches, data_time,load_times,process_times))
                all_data_times.append(data_time)

                # load_times = load_times.reshape(-1).mean()
                # process_times = process_times.reshape(-1).mean()
                all_load_times.append(load_times)
                all_process_times.append(process_times)
                batch_start_time = time.time()

                
    import matplotlib.pyplot as plt
    mean_load_time = sum(all_load_times) / len(all_load_times)
    mean_process_time = sum(all_process_times) / len(all_process_times)
    mean_data_time = sum(all_data_times) / len(all_data_times)

    # 绘制图像
    plt.figure(figsize=(10, 6))
    plt.plot(all_data_times, label="Total Data Time per Batch", color='b')
    plt.plot(all_load_times, label="Data Loading Time", color='g')
    plt.plot(all_process_times, label="Data Processing Time", color='orange')

    plt.axhline(mean_data_time, color='r', linestyle='--', label=f"Mean Total Time = {mean_data_time:.3f} s")
    plt.axhline(mean_load_time, color='g', linestyle='--', label=f"Mean Load Time = {mean_load_time:.3f} s")
    plt.axhline(mean_process_time, color='orange', linestyle='--', label=f"Mean Process Time = {mean_process_time:.3f} s")
    plt.yticks([mean_load_time,mean_process_time,mean_data_time])

    plt.xlabel('Batch')
    plt.ylabel('Time (s)')
    plt.title(f'Batchsize:{bs}, Num_workers:{num_workers}')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
parmaters = [[64,0],[64,1],[64,2],[64,4]]

for par in parmaters:
    data_test(*par)
# Out:
# [Epoch 0/10][Batch 1/3] DataTime = 7.146 (s) LoadTime = 0.226465(s) ProcessTime = 3.021940(s)
# [Epoch 0/10][Batch 2/3] DataTime = 4.436 (s) LoadTime = 0.166818(s) ProcessTime = 3.179257(s)
# [Epoch 0/10][Batch 3/3] DataTime = 4.235 (s) LoadTime = 0.192776(s) ProcessTime = 2.858629(s)
# [Epoch 1/10][Batch 1/3] DataTime = 4.362 (s) LoadTime = 0.270844(s) ProcessTime = 3.152098(s)
# [Epoch 1/10][Batch 2/3] DataTime = 4.665 (s) LoadTime = 0.222109(s) ProcessTime = 3.213216(s)
# [Epoch 1/10][Batch 3/3] DataTime = 4.440 (s) LoadTime = 0.195637(s) ProcessTime = 3.179918(s)
# [Epoch 2/10][Batch 1/3] DataTime = 4.435 (s) LoadTime = 0.299229(s) ProcessTime = 3.139213(s)
# [Epoch 2/10][Batch 2/3] DataTime = 4.628 (s) LoadTime = 0.217763(s) ProcessTime = 3.305191(s)
# [Epoch 2/10][Batch 3/3] DataTime = 4.619 (s) LoadTime = 0.209091(s) ProcessTime = 3.173193(s)
# [Epoch 3/10][Batch 1/3] DataTime = 4.632 (s) LoadTime = 0.220858(s) ProcessTime = 3.151396(s)
# [Epoch 3/10][Batch 2/3] DataTime = 4.622 (s) LoadTime = 0.146183(s) ProcessTime = 3.275928(s)
# [Epoch 3/10][Batch 3/3] DataTime = 4.344 (s) LoadTime = 0.219912(s) ProcessTime = 2.918883(s)
# [Epoch 4/10][Batch 1/3] DataTime = 4.268 (s) LoadTime = 0.206953(s) ProcessTime = 2.835920(s)
# [Epoch 4/10][Batch 2/3] DataTime = 4.701 (s) LoadTime = 0.243646(s) ProcessTime = 3.227548(s)
# [Epoch 4/10][Batch 3/3] DataTime = 4.664 (s) LoadTime = 0.206881(s) ProcessTime = 3.246152(s)
# [Epoch 5/10][Batch 1/3] DataTime = 4.686 (s) LoadTime = 0.248096(s) ProcessTime = 3.198840(s)
# [Epoch 5/10][Batch 2/3] DataTime = 4.626 (s) LoadTime = 0.233159(s) ProcessTime = 3.182329(s)
# [Epoch 5/10][Batch 3/3] DataTime = 4.525 (s) LoadTime = 0.271060(s) ProcessTime = 3.124583(s)
# [Epoch 6/10][Batch 1/3] DataTime = 4.685 (s) LoadTime = 0.220944(s) ProcessTime = 3.209175(s)
# [Epoch 6/10][Batch 2/3] DataTime = 4.417 (s) LoadTime = 0.247982(s) ProcessTime = 3.095054(s)
# [Epoch 6/10][Batch 3/3] DataTime = 4.442 (s) LoadTime = 0.212727(s) ProcessTime = 3.004327(s)
# [Epoch 7/10][Batch 1/3] DataTime = 4.573 (s) LoadTime = 0.179532(s) ProcessTime = 3.225595(s)
# [Epoch 7/10][Batch 2/3] DataTime = 3.834 (s) LoadTime = 0.202164(s) ProcessTime = 2.855611(s)
# [Epoch 7/10][Batch 3/3] DataTime = 4.294 (s) LoadTime = 0.204593(s) ProcessTime = 2.724207(s)
# [Epoch 8/10][Batch 1/3] DataTime = 3.378 (s) LoadTime = 0.212666(s) ProcessTime = 2.062785(s)
# [Epoch 8/10][Batch 2/3] DataTime = 4.552 (s) LoadTime = 0.270469(s) ProcessTime = 3.221719(s)
# [Epoch 8/10][Batch 3/3] DataTime = 4.668 (s) LoadTime = 0.213865(s) ProcessTime = 3.215955(s)
# [Epoch 9/10][Batch 1/3] DataTime = 4.208 (s) LoadTime = 0.222698(s) ProcessTime = 2.840457(s)
# [Epoch 9/10][Batch 2/3] DataTime = 4.562 (s) LoadTime = 0.292974(s) ProcessTime = 3.110934(s)
# [Epoch 9/10][Batch 3/3] DataTime = 4.551 (s) LoadTime = 0.189956(s) ProcessTime = 3.157478(s)
# [Epoch 10/10][Batch 1/3] DataTime = 3.713 (s) LoadTime = 0.214999(s) ProcessTime = 2.312206(s)
# [Epoch 10/10][Batch 2/3] DataTime = 4.458 (s) LoadTime = 0.226926(s) ProcessTime = 3.044511(s)
# [Epoch 10/10][Batch 3/3] DataTime = 4.602 (s) LoadTime = 0.244016(s) ProcessTime = 3.128274(s)
# [Epoch 0/10][Batch 1/3] DataTime = 0.477 (s) LoadTime = 0.059316(s) ProcessTime = 0.159537(s)
# [Epoch 0/10][Batch 2/3] DataTime = 0.203 (s) LoadTime = 0.087464(s) ProcessTime = 0.127894(s)
# [Epoch 0/10][Batch 3/3] DataTime = 0.207 (s) LoadTime = 0.059103(s) ProcessTime = 0.127581(s)
# [Epoch 1/10][Batch 1/3] DataTime = 0.314 (s) LoadTime = 0.060883(s) ProcessTime = 0.158656(s)
# [Epoch 1/10][Batch 2/3] DataTime = 0.248 (s) LoadTime = 0.099852(s) ProcessTime = 0.128144(s)
# [Epoch 1/10][Batch 3/3] DataTime = 0.216 (s) LoadTime = 0.064842(s) ProcessTime = 0.125068(s)
# [Epoch 2/10][Batch 1/3] DataTime = 0.406 (s) LoadTime = 0.120844(s) ProcessTime = 0.163477(s)
# [Epoch 2/10][Batch 2/3] DataTime = 0.237 (s) LoadTime = 0.090220(s) ProcessTime = 0.124974(s)
# [Epoch 2/10][Batch 3/3] DataTime = 0.225 (s) LoadTime = 0.082356(s) ProcessTime = 0.125186(s)
# [Epoch 3/10][Batch 1/3] DataTime = 0.336 (s) LoadTime = 0.056503(s) ProcessTime = 0.159006(s)
# [Epoch 3/10][Batch 2/3] DataTime = 0.213 (s) LoadTime = 0.069795(s) ProcessTime = 0.132571(s)
# [Epoch 3/10][Batch 3/3] DataTime = 0.199 (s) LoadTime = 0.058739(s) ProcessTime = 0.125892(s)
# [Epoch 4/10][Batch 1/3] DataTime = 0.343 (s) LoadTime = 0.056397(s) ProcessTime = 0.165462(s)
# [Epoch 4/10][Batch 2/3] DataTime = 0.221 (s) LoadTime = 0.081469(s) ProcessTime = 0.127907(s)
# [Epoch 4/10][Batch 3/3] DataTime = 0.257 (s) LoadTime = 0.102037(s) ProcessTime = 0.131649(s)
# [Epoch 5/10][Batch 1/3] DataTime = 0.322 (s) LoadTime = 0.052033(s) ProcessTime = 0.159400(s)
# [Epoch 5/10][Batch 2/3] DataTime = 0.204 (s) LoadTime = 0.065835(s) ProcessTime = 0.127606(s)
# [Epoch 5/10][Batch 3/3] DataTime = 0.204 (s) LoadTime = 0.046911(s) ProcessTime = 0.124495(s)
# [Epoch 6/10][Batch 1/3] DataTime = 0.329 (s) LoadTime = 0.052752(s) ProcessTime = 0.158157(s)
# [Epoch 6/10][Batch 2/3] DataTime = 0.216 (s) LoadTime = 0.069444(s) ProcessTime = 0.129941(s)
# [Epoch 6/10][Batch 3/3] DataTime = 0.205 (s) LoadTime = 0.060288(s) ProcessTime = 0.130687(s)
# [Epoch 7/10][Batch 1/3] DataTime = 0.442 (s) LoadTime = 0.162040(s) ProcessTime = 0.171325(s)
# [Epoch 7/10][Batch 2/3] DataTime = 0.213 (s) LoadTime = 0.066887(s) ProcessTime = 0.129964(s)
# [Epoch 7/10][Batch 3/3] DataTime = 0.240 (s) LoadTime = 0.083200(s) ProcessTime = 0.132832(s)
# [Epoch 8/10][Batch 1/3] DataTime = 0.312 (s) LoadTime = 0.050907(s) ProcessTime = 0.159611(s)
# [Epoch 8/10][Batch 2/3] DataTime = 0.236 (s) LoadTime = 0.067470(s) ProcessTime = 0.142391(s)
# [Epoch 8/10][Batch 3/3] DataTime = 0.209 (s) LoadTime = 0.055651(s) ProcessTime = 0.128191(s)
# [Epoch 9/10][Batch 1/3] DataTime = 0.338 (s) LoadTime = 0.052057(s) ProcessTime = 0.165263(s)
# [Epoch 9/10][Batch 2/3] DataTime = 0.216 (s) LoadTime = 0.072378(s) ProcessTime = 0.130522(s)
# [Epoch 9/10][Batch 3/3] DataTime = 0.300 (s) LoadTime = 0.084599(s) ProcessTime = 0.186228(s)
# [Epoch 10/10][Batch 1/3] DataTime = 0.390 (s) LoadTime = 0.127614(s) ProcessTime = 0.167215(s)
# [Epoch 10/10][Batch 2/3] DataTime = 0.205 (s) LoadTime = 0.057153(s) ProcessTime = 0.131233(s)
# [Epoch 10/10][Batch 3/3] DataTime = 0.222 (s) LoadTime = 0.054595(s) ProcessTime = 0.125191(s)
# [Epoch 0/10][Batch 1/3] DataTime = 0.356 (s) LoadTime = 0.059665(s) ProcessTime = 0.159578(s)
# [Epoch 0/10][Batch 2/3] DataTime = 0.001 (s) LoadTime = 0.054242(s) ProcessTime = 0.157886(s)
# [Epoch 0/10][Batch 3/3] DataTime = 0.226 (s) LoadTime = 0.077841(s) ProcessTime = 0.134919(s)
# [Epoch 1/10][Batch 1/3] DataTime = 0.440 (s) LoadTime = 0.075561(s) ProcessTime = 0.159570(s)
# [Epoch 1/10][Batch 2/3] DataTime = 0.003 (s) LoadTime = 0.085000(s) ProcessTime = 0.162352(s)
# [Epoch 1/10][Batch 3/3] DataTime = 0.239 (s) LoadTime = 0.131393(s) ProcessTime = 0.128769(s)
# [Epoch 2/10][Batch 1/3] DataTime = 0.391 (s) LoadTime = 0.094003(s) ProcessTime = 0.158625(s)
# [Epoch 2/10][Batch 2/3] DataTime = 0.026 (s) LoadTime = 0.116023(s) ProcessTime = 0.157635(s)
# [Epoch 2/10][Batch 3/3] DataTime = 0.178 (s) LoadTime = 0.067200(s) ProcessTime = 0.130400(s)
# [Epoch 3/10][Batch 1/3] DataTime = 0.404 (s) LoadTime = 0.068186(s) ProcessTime = 0.201735(s)
# [Epoch 3/10][Batch 2/3] DataTime = 0.001 (s) LoadTime = 0.054256(s) ProcessTime = 0.159403(s)
# [Epoch 3/10][Batch 3/3] DataTime = 0.213 (s) LoadTime = 0.069795(s) ProcessTime = 0.127159(s)
# [Epoch 4/10][Batch 1/3] DataTime = 0.366 (s) LoadTime = 0.074265(s) ProcessTime = 0.158100(s)
# [Epoch 4/10][Batch 2/3] DataTime = 0.001 (s) LoadTime = 0.078114(s) ProcessTime = 0.156388(s)
# [Epoch 4/10][Batch 3/3] DataTime = 0.226 (s) LoadTime = 0.096359(s) ProcessTime = 0.127374(s)
# [Epoch 5/10][Batch 1/3] DataTime = 0.346 (s) LoadTime = 0.051593(s) ProcessTime = 0.161377(s)
# [Epoch 5/10][Batch 2/3] DataTime = 0.027 (s) LoadTime = 0.056938(s) ProcessTime = 0.176661(s)
# [Epoch 5/10][Batch 3/3] DataTime = 0.179 (s) LoadTime = 0.069227(s) ProcessTime = 0.132129(s)
# [Epoch 6/10][Batch 1/3] DataTime = 0.368 (s) LoadTime = 0.063737(s) ProcessTime = 0.170077(s)
# [Epoch 6/10][Batch 2/3] DataTime = 0.001 (s) LoadTime = 0.061142(s) ProcessTime = 0.170561(s)
# [Epoch 6/10][Batch 3/3] DataTime = 0.220 (s) LoadTime = 0.088003(s) ProcessTime = 0.131745(s)
# [Epoch 7/10][Batch 1/3] DataTime = 0.436 (s) LoadTime = 0.110932(s) ProcessTime = 0.167386(s)
# [Epoch 7/10][Batch 2/3] DataTime = 0.000 (s) LoadTime = 0.116435(s) ProcessTime = 0.164760(s)
# [Epoch 7/10][Batch 3/3] DataTime = 0.191 (s) LoadTime = 0.073277(s) ProcessTime = 0.133229(s)
# [Epoch 8/10][Batch 1/3] DataTime = 0.432 (s) LoadTime = 0.121367(s) ProcessTime = 0.164707(s)
# [Epoch 8/10][Batch 2/3] DataTime = 0.001 (s) LoadTime = 0.105700(s) ProcessTime = 0.162033(s)
# [Epoch 8/10][Batch 3/3] DataTime = 0.204 (s) LoadTime = 0.079134(s) ProcessTime = 0.125024(s)
# [Epoch 9/10][Batch 1/3] DataTime = 0.398 (s) LoadTime = 0.107507(s) ProcessTime = 0.164442(s)
# [Epoch 9/10][Batch 2/3] DataTime = 0.001 (s) LoadTime = 0.095039(s) ProcessTime = 0.163087(s)
# [Epoch 9/10][Batch 3/3] DataTime = 0.225 (s) LoadTime = 0.067295(s) ProcessTime = 0.132120(s)
# [Epoch 10/10][Batch 1/3] DataTime = 0.429 (s) LoadTime = 0.122212(s) ProcessTime = 0.168744(s)
# [Epoch 10/10][Batch 2/3] DataTime = 0.001 (s) LoadTime = 0.050634(s) ProcessTime = 0.162575(s)
# [Epoch 10/10][Batch 3/3] DataTime = 0.211 (s) LoadTime = 0.074288(s) ProcessTime = 0.135244(s)
# [Epoch 0/10][Batch 1/3] DataTime = 0.461 (s) LoadTime = 0.072907(s) ProcessTime = 0.169675(s)
# [Epoch 0/10][Batch 2/3] DataTime = 0.001 (s) LoadTime = 0.082740(s) ProcessTime = 0.160245(s)
# [Epoch 0/10][Batch 3/3] DataTime = 0.000 (s) LoadTime = 0.086045(s) ProcessTime = 0.158875(s)
# [Epoch 1/10][Batch 1/3] DataTime = 0.447 (s) LoadTime = 0.060236(s) ProcessTime = 0.160531(s)
# [Epoch 1/10][Batch 2/3] DataTime = 0.001 (s) LoadTime = 0.063521(s) ProcessTime = 0.168889(s)
# [Epoch 1/10][Batch 3/3] DataTime = 0.000 (s) LoadTime = 0.059350(s) ProcessTime = 0.162339(s)
# [Epoch 2/10][Batch 1/3] DataTime = 0.461 (s) LoadTime = 0.069193(s) ProcessTime = 0.189140(s)
# [Epoch 2/10][Batch 2/3] DataTime = 0.001 (s) LoadTime = 0.062054(s) ProcessTime = 0.172098(s)
# [Epoch 2/10][Batch 3/3] DataTime = 0.000 (s) LoadTime = 0.068356(s) ProcessTime = 0.191272(s)
# [Epoch 3/10][Batch 1/3] DataTime = 0.485 (s) LoadTime = 0.128986(s) ProcessTime = 0.166376(s)
# [Epoch 3/10][Batch 2/3] DataTime = 0.001 (s) LoadTime = 0.072507(s) ProcessTime = 0.161207(s)
# [Epoch 3/10][Batch 3/3] DataTime = 0.000 (s) LoadTime = 0.118446(s) ProcessTime = 0.166215(s)
# [Epoch 4/10][Batch 1/3] DataTime = 0.415 (s) LoadTime = 0.065368(s) ProcessTime = 0.161237(s)
# [Epoch 4/10][Batch 2/3] DataTime = 0.001 (s) LoadTime = 0.069038(s) ProcessTime = 0.158251(s)
# [Epoch 4/10][Batch 3/3] DataTime = 0.022 (s) LoadTime = 0.075181(s) ProcessTime = 0.161473(s)
# [Epoch 5/10][Batch 1/3] DataTime = 0.425 (s) LoadTime = 0.058179(s) ProcessTime = 0.160951(s)
# [Epoch 5/10][Batch 2/3] DataTime = 0.001 (s) LoadTime = 0.058685(s) ProcessTime = 0.161277(s)
# [Epoch 5/10][Batch 3/3] DataTime = 0.000 (s) LoadTime = 0.062305(s) ProcessTime = 0.167853(s)
# [Epoch 6/10][Batch 1/3] DataTime = 0.472 (s) LoadTime = 0.130082(s) ProcessTime = 0.167310(s)
# [Epoch 6/10][Batch 2/3] DataTime = 0.001 (s) LoadTime = 0.069744(s) ProcessTime = 0.161809(s)
# [Epoch 6/10][Batch 3/3] DataTime = 0.071 (s) LoadTime = 0.188279(s) ProcessTime = 0.180056(s)
# [Epoch 7/10][Batch 1/3] DataTime = 0.515 (s) LoadTime = 0.072388(s) ProcessTime = 0.165121(s)
# [Epoch 7/10][Batch 2/3] DataTime = 0.001 (s) LoadTime = 0.076935(s) ProcessTime = 0.159970(s)
# [Epoch 7/10][Batch 3/3] DataTime = 0.000 (s) LoadTime = 0.074278(s) ProcessTime = 0.162368(s)
# [Epoch 8/10][Batch 1/3] DataTime = 0.418 (s) LoadTime = 0.056095(s) ProcessTime = 0.160117(s)
# [Epoch 8/10][Batch 2/3] DataTime = 0.001 (s) LoadTime = 0.056390(s) ProcessTime = 0.160062(s)
# [Epoch 8/10][Batch 3/3] DataTime = 0.000 (s) LoadTime = 0.060448(s) ProcessTime = 0.159198(s)
# [Epoch 9/10][Batch 1/3] DataTime = 0.517 (s) LoadTime = 0.150307(s) ProcessTime = 0.163944(s)
# [Epoch 9/10][Batch 2/3] DataTime = 0.001 (s) LoadTime = 0.152882(s) ProcessTime = 0.169562(s)
# [Epoch 9/10][Batch 3/3] DataTime = 0.024 (s) LoadTime = 0.145350(s) ProcessTime = 0.167334(s)
# [Epoch 10/10][Batch 1/3] DataTime = 0.474 (s) LoadTime = 0.109407(s) ProcessTime = 0.160312(s)
# [Epoch 10/10][Batch 2/3] DataTime = 0.001 (s) LoadTime = 0.109560(s) ProcessTime = 0.159012(s)
# [Epoch 10/10][Batch 3/3] DataTime = 0.033 (s) LoadTime = 0.104056(s) ProcessTime = 0.191668(s)
