# %%
import matplotlib.pyplot as plt
import os
import glob
import json
import csv

# %%
directory_path = "/home_nfs/fucheng.niu/Data_time_test/data/GT"

data_line = []
for root, dirs, files in os.walk(directory_path):
    for file in files:
        if file.endswith(".dat"):
            data_line.append(f'{root.split("/")[-2]};{root.split("/")[-1]};{file.split(".")[0]}')
            print(f'{root.split("/")[-2]};{root.split("/")[-1]};{file.split(".")[0]}')
            filepath = os.path.join(root, file)

with open("test_list2.txt","w") as f:
    for line in data_line:
        f.write(line + '\n')

with open("train_list2.txt","w") as f:
    for line in data_line:
        f.write(line + '\n')
# Out:
# 02691156;1a04e3eab45ca15dd86060f189eb133;00
# 02691156;1a04e3eab45ca15dd86060f189eb133;01
# 02691156;1a04e3eab45ca15dd86060f189eb133;02
# 02691156;1a04e3eab45ca15dd86060f189eb133;03
# 02691156;1a04e3eab45ca15dd86060f189eb133;04
# 02691156;1a04e3eab45ca15dd86060f189eb133;05
# 02691156;1a04e3eab45ca15dd86060f189eb133;06
# 02691156;1a04e3eab45ca15dd86060f189eb133;07
# 02691156;1a04e3eab45ca15dd86060f189eb133;08
# 02691156;1a04e3eab45ca15dd86060f189eb133;09
# 02691156;1a04e3eab45ca15dd86060f189eb133;10
# 02691156;1a04e3eab45ca15dd86060f189eb133;11
# 02691156;1a04e3eab45ca15dd86060f189eb133;12
# 02691156;1a04e3eab45ca15dd86060f189eb133;13
# 02691156;1a04e3eab45ca15dd86060f189eb133;14
# 02691156;1a04e3eab45ca15dd86060f189eb133;15
# 02691156;1a04e3eab45ca15dd86060f189eb133;16
# 02691156;1a04e3eab45ca15dd86060f189eb133;17
# 02691156;1a04e3eab45ca15dd86060f189eb133;18
# 02691156;1a04e3eab45ca15dd86060f189eb133;19
# 02691156;1a04e3eab45ca15dd86060f189eb133;20
# ...
